# %% [markdown]
# Analise Estatistica da Base do teste Limpa

# %%
import pandas as pd
df_base_limpa = pd.read_csv(r'C:\RPA\desafio_projetos\desafio_fadesp\desafio-fadesp-processo-seletivo\resolucao-teste\base-limpa.csv')

# %%
# visualização do df
df_base_limpa.head()
# Out:
#    Unnamed: 0  ID da Linha     ID do Pedido Data do Pedido Data de Envio  \
# 0           0        42433     AG-2011-2040            NaN           NaN
# 1           1        22253    IN-2011-47883            NaN           NaN
# 2           2        48883     HU-2011-1220            NaN           NaN
# 3           3        11731  IT-2011-3647632            NaN           NaN
# 4           4        22255    IN-2011-47883            NaN           NaN
#
#   Modalidade de Envio ID do Cliente  Nome do Cliente     Segmento  \
# 0      Standard Class      TB-11280  Toby Braunhardt     Consumer
# 1      Standard Class      JH-15985      Joseph Holt     Consumer
# 2        Second Class        AT-735    Annie Thurman     Consumer
# 3        Second Class      EM-14140     Eugene Moren  Home Office
# 4      Standard Class      JH-15985      Joseph Holt     Consumer
#
#         Cidade  ...     ID do Produto        Categoria Subcategoria  \
# ...

# %% [markdown]
# Respondendo as primeiras analise do teste -> Entendimento dos dados

# %%
# visualizando dados descritivos da base
df_base_limpa.describe()
# Out:
#         Unnamed: 0  ID da Linha        Vendas    Quantidade      Desconto  \
# count  51290.00000  51290.00000  51290.000000  51290.000000  51290.000000
# mean   25644.50000  25645.50000    246.490581      3.476545      0.142908
# std    14806.29199  14806.29199    487.565361      2.278766      0.212280
# min        0.00000      1.00000      0.444000      1.000000      0.000000
# 25%    12822.25000  12823.25000     30.758625      2.000000      0.000000
# 50%    25644.50000  25645.50000     85.053000      3.000000      0.000000
# 75%    38466.75000  38467.75000    251.053200      5.000000      0.200000
# max    51289.00000  51290.00000  22638.480000     14.000000      0.850000
#
#               Lucro  Custo de Envio
# count  51290.000000    51290.000000
# mean      28.610982       26.375915
# std      174.340972       57.296804
# min    -6599.978000        0.000000
# 25%        0.000000        2.610000
# 50%        9.240000        7.790000
# 75%       36.810000       24.450000
# ...

# %%
# visualização de dados categoricos da base 
df_base_limpa.select_dtypes(include='object').nunique()
# Out:
# ID do Pedido            25035
# Data do Pedido            865
# Data de Envio             884
# Modalidade de Envio         4
# ID do Cliente            1590
# Nome do Cliente           795
# Segmento                    3
# Cidade                   3636
# Estado                   1094
# País                      147
# Mercado                     7
# Região                     13
# ID do Produto           10292
# Categoria                   3
# Subcategoria               17
# Nome do Produto          3788
# Prioridade do Pedido        4
# dtype: int64
